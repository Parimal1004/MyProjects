# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from xgboost import XGBRegressor
import pickle

# %%
df = pd.read_csv("demand_forecasting.csv")

# %%
df.columns
# Out:
# Index(['Date', 'Store ID', 'Product ID', 'Category', 'Region',
#        'Inventory Level', 'Units Sold', 'Units Ordered', 'Price', 'Discount',
#        'Weather Condition', 'Promotion', 'Competitor Pricing', 'Seasonality',
#        'Epidemic', 'Demand'],
#       dtype='object')

# %%
features=["Price","Discount","Inventory Level","Promotion","Competitor Pricing","Category"]

# %%
target="Demand"

# %%
x=df[features].copy()
y=df[target]

# %%
label_encoders={}
categorical_cols=x.select_dtypes(include="object").columns

# %%
for col in categorical_cols:
    le=LabelEncoder()
    x[col]=le.fit_transform(x[col])
    label_encoders[col]=le

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
xgb=XGBRegressor(objective="reg:squarederror",n_jobs=-1)

# %%
param_dict={
    "n_estimators":[200,300,500],
    "max_depth":[3,4,6,8],
    "learning_rate":[0.01,0.05,0.1],
    "subsample":[0.7,0.8,1.0],
    "colsample_bytree":[0.7,0.8,1.0],
    "min_child_weight":[1,3,5]
}

# %%
random_search=RandomizedSearchCV(
    estimator=xgb,param_distributions=param_dict,n_iter=25,scoring="neg_mean_absolute_error",cv=3,verbose=1,n_jobs=-1)

# %%
random_search.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=True,
#                                           eval_metric=None, feature_types=None,
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints...
# ...

# %%
random_search.best_params_
# Out:
# {'subsample': 1.0,
#  'n_estimators': 500,
#  'min_child_weight': 1,
#  'max_depth': 8,
#  'learning_rate': 0.05,
#  'colsample_bytree': 1.0}

# %%
best_model=random_search.best_estimator_

# %%
y_pred=best_model.predict(X_test)

# %%
from sklearn.metrics import root_mean_squared_error

rmse = root_mean_squared_error(y_test, y_pred)
print(rmse)
# Out:
# 36.46744155883789

# %%
feature_importances = pd.Series(best_model.feature_importances_,index=x.columns).sort_values(ascending=False)
feature_importances
# Out:
# Promotion             0.586016
# Category              0.266436
# Price                 0.075878
# Competitor Pricing    0.027408
# Inventory Level       0.022716
# Discount              0.021545
# dtype: float32

# %%
feature_importances.plot(kind="bar",title="feature_importances")
# Out:
# <Axes: title={'center': 'feature_importances'}>

# %%
with open("label_encoders.pkl","wb") as f1:
    pickle.dump(label_encoders,f1)

# %%
with open("xgboost_demand_model.pkl","wb") as f:
    pickle.dump(best_model,f)
